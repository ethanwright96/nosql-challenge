# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with:
# 1. cd "C:\Users\e.a.wright\nosql-challenge\Starter_Code\Resources"
# 2. mongoimport --db uk_food --collection establishments --file establishments.json --jsonArray

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'fruits_db', 'gardenDB', 'local', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 254719,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6499a6a6dc9452586f3d0ef5'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
document = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
result = establishments.insert_one(document)

# %%
# Check that the new restaurant was inserted
if result.inserted_id:
    print("Document inserted successfully.")
else:
    print("Failed to insert document.")
# Out:
# Document inserted successfully.

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
business_type_id = establishments.find_one({"BusinessType":"Restaurant/Cafe/Canteen"}, {"BusinessTypeID":1, "BusinessType":1, "_id":0})

# %%
business_type_id
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({"BusinessName": "Penang Flavours"}, {"$set":{"BusinessTypeID":business_type_id["BusinessTypeID"]}})

# %%
# Confirm that the new restaurant was updated
establishments.find_one({"BusinessName":"Penang Flavours"}, {"BusinessName":1,"BusinessTypeID":1, "BusinessType":1, "_id":0})
# Out:
# {'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_count = establishments.count_documents({"LocalAuthorityName":"Dover"})
print(f"There are {dover_count} establishments in Dover.")
# Out:
# There are 994 establishments in Dover.

# %%
# Delete all documents where LocalAuthorityName is "Dover"
deleteDover = establishments.delete_many({"LocalAuthorityName":"Dover"})
# Confirm that the documents were deleted
deleteDover.deleted_count
# Out:
# 994

# %%
# Check if any remaining documents include Dover
filter = {
    "LocalAuthorityName": "Dover"
}

# Retrieve a count of the documents abiding by the filter
count = establishments.count_documents(filter)

# Print the remaining document count in an f string
print(f'There are {count} documents remaining with the LocalAuthorityName "Dover"')
# Out:
# There are 0 documents remaining with the LocalAuthorityName "Dover"

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('6499a6a6dc9452586f3d11dc'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Specify the fields to be updated
filter = {
    "geocode.longitude":{"$type":"string"},
    "geocode.latitude":{"$type":"string"}
}
# Specify the update to be imposed
update = {
    "$set":{
        "geocode.longitude":{"$toDouble":"$geocode.longitude"},
        "geocode.latitude":{"$toDouble":"$geocode.latitude"}
    }
}
# Assign establishments.update_many() with filter and update as arguments to variable result
result = establishments.update_many(filter, update)
result.modified_count
# Out:
# 38786

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Get the unique values in the RatingValue field from establishments
ratings = establishments.distinct("RatingValue")
# Print the unique values
print(ratings)
# Out:
# ['0', '1', '2', '3', '4', '5', 'Awaiting Inspection', 'AwaitingInspection', 'AwaitingPublication', 'Exempt', 'Pass']

# %%
# Coerce the non-numeric values (including 0 because it is outside of the 1-5 range) in RatingValue to null

# Create a list of numeric strings of the RatingValue field (1-5)
numeric_ratings = ['1','2','3','4','5']
# Set non 1-5 Rating Values to Null
establishments.update_many({"RatingValue":{"$nin":numeric_ratings}}, {"$set":{"RatingValue":None}})

# Query the database for documents with RatingValue of Null
null_ratings = establishments.count_documents({"RatingValue":None})
# Print the count of the documents with RatingValue of Null
print(f'There are now {null_ratings} documents with a null RatingValue.')
# Out:
# There are now 4157 documents with a null RatingValue.

# %%
# Change the data type from String to Integer for RatingValue
documents = establishments.find({"RatingValue": {"$exists": True}})
for doc in documents:
    rating_value = doc["RatingValue"]
    if rating_value is not None:
        try:
            new_rating_value = int(rating_value)
            establishments.update_one({"_id": doc["_id"]}, {"$set": {"RatingValue": new_rating_value}})
            print(f'Updated {doc["_id"]} to {new_rating_value}.')
        except ValueError:
            print(f'Could not convert {rating_value} to an integer.')
    else:
        print('RatingValue is None')
# Out:
# Updated 6499a6a6dc9452586f3d11dc to 5.
# Updated 6499a6a6dc9452586f3d11dd to 5.
# Updated 6499a6a6dc9452586f3d11e0 to 5.
# Updated 6499a6a6dc9452586f3d11e1 to 4.
# Updated 6499a6a6dc9452586f3d11e2 to 5.
# Updated 6499a6a6dc9452586f3d11e3 to 5.
# Updated 6499a6a6dc9452586f3d11e4 to 5.
# Updated 6499a6a6dc9452586f3d11e5 to 5.
# Updated 6499a6a6dc9452586f3d11e6 to 5.
# Updated 6499a6a6dc9452586f3d11e7 to 5.
# Updated 6499a6a6dc9452586f3d11e8 to 5.
# Updated 6499a6a6dc9452586f3d11e9 to 5.
# Updated 6499a6a6dc9452586f3d11ea to 4.
# Updated 6499a6a6dc9452586f3d11eb to 5.
# Updated 6499a6a6dc9452586f3d11ec to 4.
# Updated 6499a6a6dc9452586f3d11ed to 5.
# Updated 6499a6a6dc9452586f3d11ee to 5.
# Updated 6499a6a6dc9452586f3d11ef to 3.
# Updated 6499a6a6dc9452586f3d11f0 to 4.
# Updated 6499a6a6dc9452586f3d11f1 to 3.
# Updated 6499a6a6dc9452586f3d11f2 to 5.
# Updated 6499a6a6dc9452586f3d11f3 to 5.
# Updated 6499a6a6dc9452586f3d11f4 to 5.
# Updated 6499a6a6dc9452586f3d11f5 to 5.
# Updated 6499a6a6dc9452586f3d11f6 to 5.
# Updated 6499a6a6dc9452586f3d11f7 to 2.
# Updated 6499a6a6dc9452586f3d11f8 to 5.
# Updated 6499a6a6dc9452586f3d11f9 to 5.
# Updated 6499a6a6dc9452586f3d11fa to 4.
# Updated 6499a6a6dc9452586f3d11fb to 5.
# Updated 6499a6a6dc9452586f3d11fc to 5.
# Updated 6499a6a6dc9452586f3d11fd to 4.
# Updated 6499a6a6dc9452586f3d11fe to 4.
# Updated 6499a6a6dc9452586f3d11ff to 5.
# Updated 6499a6a6dc9452586f3d1200 to 2.
# Updated 6499a6a6dc9452586f3d1201 to 5.
# Updated 6499a6a6dc9452586f3d1202 to 5.
# Updated 6499a6a6dc9452586f3d1203 to 5.
# Updated 6499a6a6dc9452586f3d1204 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1206 to 5.
# Updated 6499a6a6dc9452586f3d1207 to 3.
# Updated 6499a6a6dc9452586f3d1209 to 5.
# Updated 6499a6a6dc9452586f3d120a to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d120c to 2.
# Updated 6499a6a6dc9452586f3d120d to 5.
# Updated 6499a6a6dc9452586f3d120e to 5.
# Updated 6499a6a6dc9452586f3d120f to 5.
# Updated 6499a6a6dc9452586f3d1210 to 5.
# Updated 6499a6a6dc9452586f3d1212 to 5.
# Updated 6499a6a6dc9452586f3d1214 to 5.
# Updated 6499a6a6dc9452586f3d1215 to 5.
# Updated 6499a6a6dc9452586f3d1216 to 3.
# Updated 6499a6a6dc9452586f3d1217 to 5.
# Updated 6499a6a6dc9452586f3d1218 to 5.
# Updated 6499a6a6dc9452586f3d121a to 5.
# Updated 6499a6a6dc9452586f3d121b to 5.
# Updated 6499a6a6dc9452586f3d121c to 5.
# Updated 6499a6a6dc9452586f3d121d to 5.
# Updated 6499a6a6dc9452586f3d121e to 3.
# Updated 6499a6a6dc9452586f3d1220 to 2.
# Updated 6499a6a6dc9452586f3d1221 to 5.
# Updated 6499a6a6dc9452586f3d1222 to 5.
# Updated 6499a6a6dc9452586f3d1225 to 5.
# Updated 6499a6a6dc9452586f3d1226 to 5.
# Updated 6499a6a6dc9452586f3d1228 to 5.
# Updated 6499a6a6dc9452586f3d1229 to 5.
# Updated 6499a6a6dc9452586f3d122a to 5.
# Updated 6499a6a6dc9452586f3d122b to 4.
# Updated 6499a6a6dc9452586f3d122c to 4.
# Updated 6499a6a6dc9452586f3d122d to 3.
# Updated 6499a6a6dc9452586f3d122e to 5.
# Updated 6499a6a6dc9452586f3d122f to 4.
# Updated 6499a6a6dc9452586f3d1230 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1232 to 5.
# Updated 6499a6a6dc9452586f3d1233 to 4.
# Updated 6499a6a6dc9452586f3d1234 to 5.
# Updated 6499a6a6dc9452586f3d1235 to 5.
# Updated 6499a6a6dc9452586f3d1236 to 5.
# Updated 6499a6a6dc9452586f3d1237 to 4.
# Updated 6499a6a6dc9452586f3d1238 to 5.
# Updated 6499a6a6dc9452586f3d1239 to 5.
# Updated 6499a6a6dc9452586f3d123a to 5.
# Updated 6499a6a6dc9452586f3d123b to 5.
# Updated 6499a6a6dc9452586f3d123c to 5.
# Updated 6499a6a6dc9452586f3d123d to 5.
# Updated 6499a6a6dc9452586f3d123e to 5.
# Updated 6499a6a6dc9452586f3d1240 to 5.
# Updated 6499a6a6dc9452586f3d1241 to 4.
# Updated 6499a6a6dc9452586f3d1242 to 3.
# Updated 6499a6a6dc9452586f3d1243 to 5.
# Updated 6499a6a6dc9452586f3d1244 to 4.
# Updated 6499a6a6dc9452586f3d1245 to 5.
# Updated 6499a6a6dc9452586f3d1246 to 5.
# Updated 6499a6a6dc9452586f3d1247 to 5.
# Updated 6499a6a6dc9452586f3d1248 to 5.
# Updated 6499a6a6dc9452586f3d1249 to 5.
# Updated 6499a6a6dc9452586f3d124a to 5.
# Updated 6499a6a6dc9452586f3d124b to 3.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d124d to 5.
# Updated 6499a6a6dc9452586f3d124e to 5.
# Updated 6499a6a6dc9452586f3d124f to 5.
# Updated 6499a6a6dc9452586f3d1250 to 5.
# Updated 6499a6a6dc9452586f3d1251 to 5.
# Updated 6499a6a6dc9452586f3d1252 to 3.
# Updated 6499a6a6dc9452586f3d1253 to 5.
# Updated 6499a6a6dc9452586f3d1254 to 3.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1256 to 4.
# Updated 6499a6a6dc9452586f3d1257 to 5.
# Updated 6499a6a6dc9452586f3d1258 to 5.
# Updated 6499a6a6dc9452586f3d1259 to 3.
# Updated 6499a6a6dc9452586f3d125a to 5.
# Updated 6499a6a6dc9452586f3d125b to 5.
# Updated 6499a6a6dc9452586f3d125c to 5.
# Updated 6499a6a6dc9452586f3d125d to 4.
# Updated 6499a6a6dc9452586f3d125e to 4.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1260 to 2.
# Updated 6499a6a6dc9452586f3d1261 to 5.
# Updated 6499a6a6dc9452586f3d1262 to 4.
# Updated 6499a6a6dc9452586f3d1263 to 5.
# Updated 6499a6a6dc9452586f3d1264 to 4.
# Updated 6499a6a6dc9452586f3d1265 to 5.
# Updated 6499a6a6dc9452586f3d1266 to 5.
# Updated 6499a6a6dc9452586f3d1267 to 3.
# Updated 6499a6a6dc9452586f3d1268 to 5.
# Updated 6499a6a6dc9452586f3d1269 to 4.
# Updated 6499a6a6dc9452586f3d126a to 5.
# Updated 6499a6a6dc9452586f3d126b to 5.
# Updated 6499a6a6dc9452586f3d126c to 5.
# Updated 6499a6a6dc9452586f3d126d to 4.
# Updated 6499a6a6dc9452586f3d126e to 5.
# Updated 6499a6a6dc9452586f3d126f to 5.
# Updated 6499a6a6dc9452586f3d1270 to 5.
# Updated 6499a6a6dc9452586f3d1271 to 5.
# Updated 6499a6a6dc9452586f3d1272 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1274 to 3.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1276 to 5.
# Updated 6499a6a6dc9452586f3d1277 to 5.
# Updated 6499a6a6dc9452586f3d1278 to 5.
# Updated 6499a6a6dc9452586f3d1279 to 3.
# Updated 6499a6a6dc9452586f3d127a to 5.
# Updated 6499a6a6dc9452586f3d127b to 5.
# Updated 6499a6a6dc9452586f3d127c to 4.
# Updated 6499a6a6dc9452586f3d127d to 5.
# Updated 6499a6a6dc9452586f3d127e to 5.
# Updated 6499a6a6dc9452586f3d127f to 5.
# Updated 6499a6a6dc9452586f3d1281 to 5.
# Updated 6499a6a6dc9452586f3d1282 to 1.
# Updated 6499a6a6dc9452586f3d1283 to 4.
# Updated 6499a6a6dc9452586f3d1284 to 5.
# Updated 6499a6a6dc9452586f3d1285 to 5.
# Updated 6499a6a6dc9452586f3d1286 to 5.
# Updated 6499a6a6dc9452586f3d1287 to 4.
# Updated 6499a6a6dc9452586f3d1288 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d128c to 5.
# Updated 6499a6a6dc9452586f3d128d to 5.
# Updated 6499a6a6dc9452586f3d128e to 5.
# Updated 6499a6a6dc9452586f3d128f to 5.
# Updated 6499a6a6dc9452586f3d1290 to 5.
# Updated 6499a6a6dc9452586f3d1291 to 5.
# Updated 6499a6a6dc9452586f3d1292 to 5.
# Updated 6499a6a6dc9452586f3d1293 to 5.
# Updated 6499a6a6dc9452586f3d1294 to 5.
# Updated 6499a6a6dc9452586f3d1295 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1297 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1299 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d129b to 4.
# Updated 6499a6a6dc9452586f3d129c to 5.
# Updated 6499a6a6dc9452586f3d129d to 5.
# Updated 6499a6a6dc9452586f3d129e to 5.
# Updated 6499a6a6dc9452586f3d12a0 to 5.
# Updated 6499a6a6dc9452586f3d12a1 to 5.
# Updated 6499a6a6dc9452586f3d12a2 to 5.
# Updated 6499a6a6dc9452586f3d12a3 to 5.
# Updated 6499a6a6dc9452586f3d12a4 to 5.
# Updated 6499a6a6dc9452586f3d12a5 to 3.
# Updated 6499a6a6dc9452586f3d12a6 to 5.
# Updated 6499a6a6dc9452586f3d12a7 to 2.
# Updated 6499a6a6dc9452586f3d12a8 to 5.
# Updated 6499a6a6dc9452586f3d12a9 to 5.
# Updated 6499a6a6dc9452586f3d12aa to 2.
# Updated 6499a6a6dc9452586f3d12ab to 5.
# Updated 6499a6a6dc9452586f3d12ac to 5.
# Updated 6499a6a6dc9452586f3d12ad to 5.
# Updated 6499a6a6dc9452586f3d12ae to 5.
# Updated 6499a6a6dc9452586f3d12af to 4.
# Updated 6499a6a6dc9452586f3d12b0 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d12b2 to 5.
# Updated 6499a6a6dc9452586f3d12b3 to 4.
# Updated 6499a6a6dc9452586f3d12b4 to 3.
# Updated 6499a6a6dc9452586f3d12b5 to 5.
# Updated 6499a6a6dc9452586f3d12b6 to 4.
# Updated 6499a6a6dc9452586f3d12b7 to 4.
# Updated 6499a6a6dc9452586f3d12b8 to 3.
# Updated 6499a6a6dc9452586f3d12b9 to 3.
# Updated 6499a6a6dc9452586f3d12ba to 1.
# Updated 6499a6a6dc9452586f3d12bb to 5.
# Updated 6499a6a6dc9452586f3d12bc to 5.
# Updated 6499a6a6dc9452586f3d12bd to 3.
# Updated 6499a6a6dc9452586f3d12be to 5.
# Updated 6499a6a6dc9452586f3d12bf to 5.
# Updated 6499a6a6dc9452586f3d12c0 to 5.
# Updated 6499a6a6dc9452586f3d12c1 to 5.
# Updated 6499a6a6dc9452586f3d12c2 to 4.
# Updated 6499a6a6dc9452586f3d12c3 to 5.
# Updated 6499a6a6dc9452586f3d12c4 to 5.
# Updated 6499a6a6dc9452586f3d12c5 to 5.
# Updated 6499a6a6dc9452586f3d12c6 to 4.
# Updated 6499a6a6dc9452586f3d12c7 to 4.
# Updated 6499a6a6dc9452586f3d12c8 to 5.
# Updated 6499a6a6dc9452586f3d12c9 to 5.
# Updated 6499a6a6dc9452586f3d12ca to 5.
# Updated 6499a6a6dc9452586f3d12cb to 5.
# Updated 6499a6a6dc9452586f3d12cc to 1.
# Updated 6499a6a6dc9452586f3d12cd to 5.
# Updated 6499a6a6dc9452586f3d12ce to 5.
# Updated 6499a6a6dc9452586f3d12cf to 3.
# Updated 6499a6a6dc9452586f3d12d0 to 5.
# Updated 6499a6a6dc9452586f3d12d1 to 5.
# Updated 6499a6a6dc9452586f3d12d2 to 5.
# Updated 6499a6a6dc9452586f3d12d3 to 5.
# Updated 6499a6a6dc9452586f3d12d4 to 5.
# Updated 6499a6a6dc9452586f3d12d5 to 4.
# Updated 6499a6a6dc9452586f3d12d6 to 5.
# Updated 6499a6a6dc9452586f3d12d7 to 4.
# Updated 6499a6a6dc9452586f3d12d8 to 5.
# Updated 6499a6a6dc9452586f3d12d9 to 5.
# Updated 6499a6a6dc9452586f3d12da to 5.
# Updated 6499a6a6dc9452586f3d12db to 5.
# Updated 6499a6a6dc9452586f3d12dc to 5.
# Updated 6499a6a6dc9452586f3d12dd to 5.
# Updated 6499a6a6dc9452586f3d12de to 5.
# Updated 6499a6a6dc9452586f3d12df to 4.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d12e1 to 5.
# Updated 6499a6a6dc9452586f3d12e2 to 4.
# Updated 6499a6a6dc9452586f3d12e3 to 5.
# Updated 6499a6a6dc9452586f3d12e4 to 5.
# Updated 6499a6a6dc9452586f3d12e5 to 5.
# RatingValue is None
# RatingValue is None
# Updated 6499a6a6dc9452586f3d12e8 to 5.
# Updated 6499a6a6dc9452586f3d12e9 to 4.
# Updated 6499a6a6dc9452586f3d12ea to 5.
# Updated 6499a6a6dc9452586f3d12eb to 5.
# Updated 6499a6a6dc9452586f3d12ec to 5.
# Updated 6499a6a6dc9452586f3d12ed to 3.
# Updated 6499a6a6dc9452586f3d12ee to 4.
# Updated 6499a6a6dc9452586f3d12ef to 5.
# Updated 6499a6a6dc9452586f3d12f0 to 5.
# Updated 6499a6a6dc9452586f3d12f2 to 5.
# Updated 6499a6a6dc9452586f3d12f3 to 4.
# Updated 6499a6a6dc9452586f3d12f4 to 3.
# Updated 6499a6a6dc9452586f3d12f5 to 5.
# Updated 6499a6a6dc9452586f3d12f6 to 4.
# Updated 6499a6a6dc9452586f3d12f7 to 3.
# Updated 6499a6a6dc9452586f3d12f8 to 5.
# Updated 6499a6a6dc9452586f3d12f9 to 5.
# Updated 6499a6a6dc9452586f3d12fa to 3.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d12fc to 5.
# Updated 6499a6a6dc9452586f3d12fd to 5.
# Updated 6499a6a6dc9452586f3d12fe to 5.
# Updated 6499a6a6dc9452586f3d12ff to 5.
# Updated 6499a6a6dc9452586f3d1300 to 5.
# Updated 6499a6a6dc9452586f3d1301 to 5.
# Updated 6499a6a6dc9452586f3d1302 to 4.
# Updated 6499a6a6dc9452586f3d1303 to 4.
# Updated 6499a6a6dc9452586f3d1304 to 2.
# Updated 6499a6a6dc9452586f3d1305 to 5.
# Updated 6499a6a6dc9452586f3d1306 to 5.
# Updated 6499a6a6dc9452586f3d1307 to 4.
# Updated 6499a6a6dc9452586f3d1308 to 5.
# Updated 6499a6a6dc9452586f3d1309 to 5.
# Updated 6499a6a6dc9452586f3d130a to 4.
# Updated 6499a6a6dc9452586f3d130b to 4.
# Updated 6499a6a6dc9452586f3d130c to 5.
# Updated 6499a6a6dc9452586f3d130d to 4.
# Updated 6499a6a6dc9452586f3d130e to 5.
# Updated 6499a6a6dc9452586f3d130f to 5.
# Updated 6499a6a6dc9452586f3d1310 to 4.
# Updated 6499a6a6dc9452586f3d1311 to 5.
# Updated 6499a6a6dc9452586f3d1313 to 4.
# Updated 6499a6a6dc9452586f3d1314 to 4.
# Updated 6499a6a6dc9452586f3d1315 to 5.
# Updated 6499a6a6dc9452586f3d1316 to 5.
# Updated 6499a6a6dc9452586f3d1317 to 5.
# Updated 6499a6a6dc9452586f3d1318 to 5.
# Updated 6499a6a6dc9452586f3d1319 to 5.
# Updated 6499a6a6dc9452586f3d131a to 5.
# Updated 6499a6a6dc9452586f3d131c to 2.
# Updated 6499a6a6dc9452586f3d131d to 5.
# Updated 6499a6a6dc9452586f3d131e to 5.
# Updated 6499a6a6dc9452586f3d131f to 5.
# Updated 6499a6a6dc9452586f3d1320 to 4.
# Updated 6499a6a6dc9452586f3d1321 to 5.
# Updated 6499a6a6dc9452586f3d1322 to 5.
# Updated 6499a6a6dc9452586f3d1323 to 5.
# Updated 6499a6a6dc9452586f3d1324 to 5.
# Updated 6499a6a6dc9452586f3d1325 to 4.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1327 to 5.
# Updated 6499a6a6dc9452586f3d1328 to 5.
# Updated 6499a6a6dc9452586f3d1329 to 1.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d132b to 5.
# Updated 6499a6a6dc9452586f3d132c to 5.
# Updated 6499a6a6dc9452586f3d132e to 5.
# Updated 6499a6a6dc9452586f3d132f to 5.
# Updated 6499a6a6dc9452586f3d1330 to 5.
# Updated 6499a6a6dc9452586f3d1331 to 5.
# Updated 6499a6a6dc9452586f3d1332 to 5.
# Updated 6499a6a6dc9452586f3d1333 to 5.
# Updated 6499a6a6dc9452586f3d1335 to 4.
# Updated 6499a6a6dc9452586f3d1336 to 5.
# Updated 6499a6a6dc9452586f3d1338 to 5.
# Updated 6499a6a6dc9452586f3d1339 to 5.
# Updated 6499a6a6dc9452586f3d133b to 5.
# Updated 6499a6a6dc9452586f3d133d to 5.
# Updated 6499a6a6dc9452586f3d1340 to 5.
# Updated 6499a6a6dc9452586f3d1342 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1345 to 5.
# Updated 6499a6a6dc9452586f3d1346 to 5.
# Updated 6499a6a6dc9452586f3d1349 to 5.
# Updated 6499a6a6dc9452586f3d134b to 5.
# Updated 6499a6a6dc9452586f3d134c to 5.
# Updated 6499a6a6dc9452586f3d134e to 5.
# Updated 6499a6a6dc9452586f3d134f to 5.
# Updated 6499a6a6dc9452586f3d1351 to 5.
# Updated 6499a6a6dc9452586f3d1352 to 5.
# Updated 6499a6a6dc9452586f3d1353 to 5.
# Updated 6499a6a6dc9452586f3d1354 to 5.
# Updated 6499a6a6dc9452586f3d1355 to 5.
# Updated 6499a6a6dc9452586f3d1356 to 5.
# Updated 6499a6a6dc9452586f3d1357 to 5.
# Updated 6499a6a6dc9452586f3d1358 to 5.
# Updated 6499a6a6dc9452586f3d1359 to 5.
# Updated 6499a6a6dc9452586f3d135a to 5.
# Updated 6499a6a6dc9452586f3d135b to 5.
# Updated 6499a6a6dc9452586f3d135d to 5.
# Updated 6499a6a6dc9452586f3d135e to 5.
# Updated 6499a6a6dc9452586f3d135f to 5.
# Updated 6499a6a6dc9452586f3d1360 to 5.
# Updated 6499a6a6dc9452586f3d1361 to 5.
# Updated 6499a6a6dc9452586f3d1362 to 5.
# Updated 6499a6a6dc9452586f3d1363 to 5.
# Updated 6499a6a6dc9452586f3d1364 to 5.
# Updated 6499a6a6dc9452586f3d1365 to 5.
# Updated 6499a6a6dc9452586f3d1366 to 5.
# Updated 6499a6a6dc9452586f3d1367 to 5.
# Updated 6499a6a6dc9452586f3d1368 to 4.
# Updated 6499a6a6dc9452586f3d1369 to 5.
# Updated 6499a6a6dc9452586f3d136a to 5.
# Updated 6499a6a6dc9452586f3d136b to 5.
# Updated 6499a6a6dc9452586f3d136c to 5.
# Updated 6499a6a6dc9452586f3d136d to 5.
# Updated 6499a6a6dc9452586f3d136e to 5.
# Updated 6499a6a6dc9452586f3d136f to 4.
# Updated 6499a6a6dc9452586f3d1371 to 5.
# Updated 6499a6a6dc9452586f3d1372 to 5.
# Updated 6499a6a6dc9452586f3d1373 to 5.
# Updated 6499a6a6dc9452586f3d1374 to 5.
# Updated 6499a6a6dc9452586f3d1375 to 5.
# Updated 6499a6a6dc9452586f3d1376 to 5.
# Updated 6499a6a6dc9452586f3d1378 to 5.
# Updated 6499a6a6dc9452586f3d1379 to 4.
# Updated 6499a6a6dc9452586f3d137a to 5.
# Updated 6499a6a6dc9452586f3d137b to 5.
# Updated 6499a6a6dc9452586f3d137c to 5.
# Updated 6499a6a6dc9452586f3d137d to 5.
# Updated 6499a6a6dc9452586f3d137e to 5.
# Updated 6499a6a6dc9452586f3d137f to 5.
# Updated 6499a6a6dc9452586f3d1380 to 5.
# Updated 6499a6a6dc9452586f3d1381 to 5.
# Updated 6499a6a6dc9452586f3d1382 to 5.
# Updated 6499a6a6dc9452586f3d1383 to 5.
# Updated 6499a6a6dc9452586f3d1384 to 5.
# Updated 6499a6a6dc9452586f3d1385 to 5.
# Updated 6499a6a6dc9452586f3d1387 to 4.
# Updated 6499a6a6dc9452586f3d1388 to 5.
# Updated 6499a6a6dc9452586f3d1389 to 5.
# Updated 6499a6a6dc9452586f3d138d to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d138f to 4.
# Updated 6499a6a6dc9452586f3d1390 to 5.
# Updated 6499a6a6dc9452586f3d1391 to 5.
# Updated 6499a6a6dc9452586f3d1392 to 5.
# Updated 6499a6a6dc9452586f3d1393 to 5.
# Updated 6499a6a6dc9452586f3d1394 to 5.
# Updated 6499a6a6dc9452586f3d1396 to 5.
# Updated 6499a6a6dc9452586f3d1397 to 5.
# Updated 6499a6a6dc9452586f3d1398 to 5.
# Updated 6499a6a6dc9452586f3d1399 to 5.
# Updated 6499a6a6dc9452586f3d139a to 5.
# Updated 6499a6a6dc9452586f3d139b to 5.
# Updated 6499a6a6dc9452586f3d139c to 5.
# Updated 6499a6a6dc9452586f3d139d to 5.
# Updated 6499a6a6dc9452586f3d139e to 5.
# Updated 6499a6a6dc9452586f3d139f to 5.
# Updated 6499a6a6dc9452586f3d13a0 to 5.
# Updated 6499a6a6dc9452586f3d13a1 to 5.
# Updated 6499a6a6dc9452586f3d13a2 to 5.
# Updated 6499a6a6dc9452586f3d13a3 to 5.
# Updated 6499a6a6dc9452586f3d13a4 to 5.
# Updated 6499a6a6dc9452586f3d13a5 to 5.
# Updated 6499a6a6dc9452586f3d13a6 to 5.
# Updated 6499a6a6dc9452586f3d13a7 to 5.
# Updated 6499a6a6dc9452586f3d13a8 to 5.
# Updated 6499a6a6dc9452586f3d13a9 to 1.
# Updated 6499a6a6dc9452586f3d13aa to 5.
# Updated 6499a6a6dc9452586f3d13ab to 5.
# Updated 6499a6a6dc9452586f3d13ac to 5.
# Updated 6499a6a6dc9452586f3d13ad to 5.
# Updated 6499a6a6dc9452586f3d13ae to 5.
# Updated 6499a6a6dc9452586f3d13af to 5.
# Updated 6499a6a6dc9452586f3d13b0 to 5.
# Updated 6499a6a6dc9452586f3d13b1 to 5.
# Updated 6499a6a6dc9452586f3d13b2 to 5.
# Updated 6499a6a6dc9452586f3d13b3 to 5.
# Updated 6499a6a6dc9452586f3d13b4 to 5.
# Updated 6499a6a6dc9452586f3d13b5 to 5.
# Updated 6499a6a6dc9452586f3d13b6 to 5.
# Updated 6499a6a6dc9452586f3d13b7 to 5.
# Updated 6499a6a6dc9452586f3d13b8 to 5.
# Updated 6499a6a6dc9452586f3d13b9 to 1.
# Updated 6499a6a6dc9452586f3d13ba to 5.
# Updated 6499a6a6dc9452586f3d13bb to 5.
# Updated 6499a6a6dc9452586f3d13bc to 5.
# Updated 6499a6a6dc9452586f3d13bd to 5.
# Updated 6499a6a6dc9452586f3d13bf to 5.
# Updated 6499a6a6dc9452586f3d13c0 to 4.
# Updated 6499a6a6dc9452586f3d13c1 to 5.
# Updated 6499a6a6dc9452586f3d13c2 to 5.
# Updated 6499a6a6dc9452586f3d13c3 to 5.
# Updated 6499a6a6dc9452586f3d13c4 to 5.
# Updated 6499a6a6dc9452586f3d13c5 to 5.
# Updated 6499a6a6dc9452586f3d13c6 to 5.
# Updated 6499a6a6dc9452586f3d13c7 to 2.
# Updated 6499a6a6dc9452586f3d13c8 to 4.
# Updated 6499a6a6dc9452586f3d13c9 to 5.
# Updated 6499a6a6dc9452586f3d13ca to 5.
# Updated 6499a6a6dc9452586f3d13cb to 5.
# Updated 6499a6a6dc9452586f3d13cc to 4.
# Updated 6499a6a6dc9452586f3d13cd to 5.
# Updated 6499a6a6dc9452586f3d13ce to 5.
# Updated 6499a6a6dc9452586f3d13cf to 5.
# Updated 6499a6a6dc9452586f3d13d0 to 5.
# Updated 6499a6a6dc9452586f3d13d1 to 5.
# Updated 6499a6a6dc9452586f3d13d2 to 3.
# Updated 6499a6a6dc9452586f3d13d3 to 4.
# Updated 6499a6a6dc9452586f3d13d4 to 5.
# Updated 6499a6a6dc9452586f3d13d5 to 5.
# Updated 6499a6a6dc9452586f3d13d6 to 5.
# Updated 6499a6a6dc9452586f3d13d7 to 5.
# Updated 6499a6a6dc9452586f3d13d8 to 5.
# Updated 6499a6a6dc9452586f3d13d9 to 5.
# Updated 6499a6a6dc9452586f3d13da to 5.
# Updated 6499a6a6dc9452586f3d13db to 5.
# Updated 6499a6a6dc9452586f3d13dc to 5.
# Updated 6499a6a6dc9452586f3d13dd to 5.
# Updated 6499a6a6dc9452586f3d13de to 5.
# Updated 6499a6a6dc9452586f3d13df to 5.
# Updated 6499a6a6dc9452586f3d13e0 to 5.
# Updated 6499a6a6dc9452586f3d13e1 to 3.
# Updated 6499a6a6dc9452586f3d13e3 to 5.
# Updated 6499a6a6dc9452586f3d13e4 to 5.
# Updated 6499a6a6dc9452586f3d13e5 to 5.
# Updated 6499a6a6dc9452586f3d13e6 to 4.
# Updated 6499a6a6dc9452586f3d13e7 to 5.
# Updated 6499a6a6dc9452586f3d13e8 to 4.
# Updated 6499a6a6dc9452586f3d13e9 to 5.
# Updated 6499a6a6dc9452586f3d13ea to 5.
# Updated 6499a6a6dc9452586f3d13eb to 5.
# Updated 6499a6a6dc9452586f3d13ec to 5.
# Updated 6499a6a6dc9452586f3d13ed to 5.
# Updated 6499a6a6dc9452586f3d13ee to 5.
# Updated 6499a6a6dc9452586f3d13ef to 5.
# Updated 6499a6a6dc9452586f3d13f0 to 5.
# Updated 6499a6a6dc9452586f3d13f1 to 5.
# Updated 6499a6a6dc9452586f3d13f2 to 5.
# Updated 6499a6a6dc9452586f3d13f3 to 5.
# Updated 6499a6a6dc9452586f3d13f4 to 5.
# Updated 6499a6a6dc9452586f3d13f5 to 5.
# Updated 6499a6a6dc9452586f3d13f6 to 5.
# Updated 6499a6a6dc9452586f3d13f7 to 5.
# Updated 6499a6a6dc9452586f3d13f8 to 5.
# Updated 6499a6a6dc9452586f3d13f9 to 5.
# Updated 6499a6a6dc9452586f3d13fa to 5.
# Updated 6499a6a6dc9452586f3d13fb to 5.
# Updated 6499a6a6dc9452586f3d13fc to 5.
# Updated 6499a6a6dc9452586f3d13fd to 5.
# Updated 6499a6a6dc9452586f3d13fe to 5.
# Updated 6499a6a6dc9452586f3d13ff to 5.
# Updated 6499a6a6dc9452586f3d1400 to 5.
# Updated 6499a6a6dc9452586f3d1401 to 5.
# Updated 6499a6a6dc9452586f3d1402 to 5.
# Updated 6499a6a6dc9452586f3d1403 to 5.
# Updated 6499a6a6dc9452586f3d1404 to 5.
# Updated 6499a6a6dc9452586f3d1405 to 5.
# Updated 6499a6a6dc9452586f3d1406 to 5.
# Updated 6499a6a6dc9452586f3d1407 to 5.
# Updated 6499a6a6dc9452586f3d1408 to 5.
# Updated 6499a6a6dc9452586f3d1409 to 5.
# Updated 6499a6a6dc9452586f3d140a to 4.
# Updated 6499a6a6dc9452586f3d140b to 5.
# Updated 6499a6a6dc9452586f3d140c to 5.
# Updated 6499a6a6dc9452586f3d140d to 4.
# Updated 6499a6a6dc9452586f3d140e to 5.
# Updated 6499a6a6dc9452586f3d140f to 5.
# Updated 6499a6a6dc9452586f3d1410 to 5.
# Updated 6499a6a6dc9452586f3d1411 to 5.
# Updated 6499a6a6dc9452586f3d1412 to 5.
# Updated 6499a6a6dc9452586f3d1413 to 5.
# Updated 6499a6a6dc9452586f3d1414 to 5.
# Updated 6499a6a6dc9452586f3d1415 to 5.
# Updated 6499a6a6dc9452586f3d1416 to 5.
# Updated 6499a6a6dc9452586f3d1417 to 5.
# Updated 6499a6a6dc9452586f3d1418 to 5.
# Updated 6499a6a6dc9452586f3d1419 to 5.
# Updated 6499a6a6dc9452586f3d141a to 5.
# Updated 6499a6a6dc9452586f3d141b to 5.
# Updated 6499a6a6dc9452586f3d141c to 5.
# Updated 6499a6a6dc9452586f3d141d to 5.
# Updated 6499a6a6dc9452586f3d141e to 5.
# Updated 6499a6a6dc9452586f3d141f to 5.
# Updated 6499a6a6dc9452586f3d1421 to 5.
# Updated 6499a6a6dc9452586f3d1422 to 5.
# Updated 6499a6a6dc9452586f3d1423 to 5.
# Updated 6499a6a6dc9452586f3d1424 to 5.
# Updated 6499a6a6dc9452586f3d1425 to 5.
# Updated 6499a6a6dc9452586f3d1426 to 4.
# Updated 6499a6a6dc9452586f3d1427 to 5.
# Updated 6499a6a6dc9452586f3d1428 to 3.
# Updated 6499a6a6dc9452586f3d1429 to 5.
# Updated 6499a6a6dc9452586f3d142a to 5.
# Updated 6499a6a6dc9452586f3d142b to 5.
# Updated 6499a6a6dc9452586f3d142c to 5.
# Updated 6499a6a6dc9452586f3d142d to 5.
# Updated 6499a6a6dc9452586f3d142e to 4.
# Updated 6499a6a6dc9452586f3d142f to 4.
# Updated 6499a6a6dc9452586f3d1430 to 5.
# Updated 6499a6a6dc9452586f3d1431 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1433 to 4.
# Updated 6499a6a6dc9452586f3d1434 to 5.
# Updated 6499a6a6dc9452586f3d1435 to 5.
# Updated 6499a6a6dc9452586f3d1436 to 4.
# Updated 6499a6a6dc9452586f3d1437 to 4.
# Updated 6499a6a6dc9452586f3d1438 to 5.
# Updated 6499a6a6dc9452586f3d1439 to 5.
# Updated 6499a6a6dc9452586f3d143a to 5.
# Updated 6499a6a6dc9452586f3d143b to 5.
# Updated 6499a6a6dc9452586f3d143c to 5.
# Updated 6499a6a6dc9452586f3d143d to 5.
# Updated 6499a6a6dc9452586f3d143e to 5.
# Updated 6499a6a6dc9452586f3d143f to 5.
# Updated 6499a6a6dc9452586f3d1440 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1442 to 5.
# Updated 6499a6a6dc9452586f3d1443 to 5.
# Updated 6499a6a6dc9452586f3d1444 to 5.
# Updated 6499a6a6dc9452586f3d1445 to 5.
# Updated 6499a6a6dc9452586f3d1446 to 5.
# Updated 6499a6a6dc9452586f3d1447 to 5.
# Updated 6499a6a6dc9452586f3d1448 to 5.
# Updated 6499a6a6dc9452586f3d1449 to 5.
# Updated 6499a6a6dc9452586f3d144a to 5.
# Updated 6499a6a6dc9452586f3d144b to 5.
# Updated 6499a6a6dc9452586f3d144c to 5.
# Updated 6499a6a6dc9452586f3d144d to 5.
# Updated 6499a6a6dc9452586f3d144e to 5.
# Updated 6499a6a6dc9452586f3d144f to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1451 to 5.
# Updated 6499a6a6dc9452586f3d1452 to 5.
# Updated 6499a6a6dc9452586f3d1453 to 3.
# Updated 6499a6a6dc9452586f3d1454 to 4.
# Updated 6499a6a6dc9452586f3d1455 to 5.
# Updated 6499a6a6dc9452586f3d1456 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1458 to 5.
# Updated 6499a6a6dc9452586f3d1459 to 5.
# Updated 6499a6a6dc9452586f3d145a to 5.
# Updated 6499a6a6dc9452586f3d145b to 5.
# Updated 6499a6a6dc9452586f3d145c to 5.
# Updated 6499a6a6dc9452586f3d145d to 5.
# Updated 6499a6a6dc9452586f3d145e to 5.
# Updated 6499a6a6dc9452586f3d145f to 5.
# Updated 6499a6a6dc9452586f3d1460 to 5.
# Updated 6499a6a6dc9452586f3d1461 to 5.
# Updated 6499a6a6dc9452586f3d1462 to 5.
# Updated 6499a6a6dc9452586f3d1463 to 5.
# Updated 6499a6a6dc9452586f3d1464 to 5.
# Updated 6499a6a6dc9452586f3d1465 to 5.
# Updated 6499a6a6dc9452586f3d1466 to 5.
# Updated 6499a6a6dc9452586f3d1467 to 5.
# Updated 6499a6a6dc9452586f3d1468 to 5.
# Updated 6499a6a6dc9452586f3d1469 to 5.
# Updated 6499a6a6dc9452586f3d146a to 5.
# Updated 6499a6a6dc9452586f3d146b to 5.
# Updated 6499a6a6dc9452586f3d146c to 5.
# Updated 6499a6a6dc9452586f3d146d to 5.
# Updated 6499a6a6dc9452586f3d146e to 5.
# Updated 6499a6a6dc9452586f3d146f to 5.
# Updated 6499a6a6dc9452586f3d1470 to 5.
# Updated 6499a6a6dc9452586f3d1471 to 5.
# Updated 6499a6a6dc9452586f3d1472 to 5.
# Updated 6499a6a6dc9452586f3d1473 to 5.
# Updated 6499a6a6dc9452586f3d1474 to 5.
# Updated 6499a6a6dc9452586f3d1475 to 5.
# Updated 6499a6a6dc9452586f3d1476 to 5.
# Updated 6499a6a6dc9452586f3d1477 to 3.
# Updated 6499a6a6dc9452586f3d1478 to 5.
# Updated 6499a6a6dc9452586f3d1479 to 4.
# Updated 6499a6a6dc9452586f3d147a to 5.
# Updated 6499a6a6dc9452586f3d147b to 5.
# Updated 6499a6a6dc9452586f3d147c to 5.
# Updated 6499a6a6dc9452586f3d147d to 3.
# Updated 6499a6a6dc9452586f3d147e to 5.
# Updated 6499a6a6dc9452586f3d147f to 5.
# Updated 6499a6a6dc9452586f3d1480 to 5.
# Updated 6499a6a6dc9452586f3d1481 to 5.
# Updated 6499a6a6dc9452586f3d1482 to 5.
# Updated 6499a6a6dc9452586f3d1483 to 4.
# Updated 6499a6a6dc9452586f3d1484 to 5.
# Updated 6499a6a6dc9452586f3d1485 to 5.
# Updated 6499a6a6dc9452586f3d1486 to 5.
# Updated 6499a6a6dc9452586f3d1487 to 5.
# Updated 6499a6a6dc9452586f3d1488 to 5.
# Updated 6499a6a6dc9452586f3d1489 to 5.
# Updated 6499a6a6dc9452586f3d148a to 5.
# Updated 6499a6a6dc9452586f3d148b to 5.
# Updated 6499a6a6dc9452586f3d148c to 5.
# Updated 6499a6a6dc9452586f3d148d to 5.
# Updated 6499a6a6dc9452586f3d148e to 5.
# Updated 6499a6a6dc9452586f3d148f to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1491 to 4.
# Updated 6499a6a6dc9452586f3d1492 to 4.
# Updated 6499a6a6dc9452586f3d1493 to 5.
# Updated 6499a6a6dc9452586f3d1494 to 5.
# Updated 6499a6a6dc9452586f3d1495 to 5.
# Updated 6499a6a6dc9452586f3d1496 to 5.
# Updated 6499a6a6dc9452586f3d1497 to 5.
# Updated 6499a6a6dc9452586f3d1498 to 2.
# Updated 6499a6a6dc9452586f3d1499 to 4.
# Updated 6499a6a6dc9452586f3d149a to 5.
# Updated 6499a6a6dc9452586f3d149b to 5.
# Updated 6499a6a6dc9452586f3d149c to 5.
# Updated 6499a6a6dc9452586f3d149d to 5.
# Updated 6499a6a6dc9452586f3d149e to 5.
# Updated 6499a6a6dc9452586f3d149f to 5.
# Updated 6499a6a6dc9452586f3d14a0 to 5.
# Updated 6499a6a6dc9452586f3d14a1 to 5.
# Updated 6499a6a6dc9452586f3d14a2 to 5.
# Updated 6499a6a6dc9452586f3d14a3 to 4.
# Updated 6499a6a6dc9452586f3d14a4 to 4.
# Updated 6499a6a6dc9452586f3d14a5 to 5.
# Updated 6499a6a6dc9452586f3d14a6 to 5.
# Updated 6499a6a6dc9452586f3d14a7 to 5.
# Updated 6499a6a6dc9452586f3d14a8 to 5.
# Updated 6499a6a6dc9452586f3d14a9 to 5.
# Updated 6499a6a6dc9452586f3d14aa to 5.
# Updated 6499a6a6dc9452586f3d14ab to 5.
# Updated 6499a6a6dc9452586f3d14ac to 5.
# Updated 6499a6a6dc9452586f3d14ae to 5.
# Updated 6499a6a6dc9452586f3d14af to 5.
# Updated 6499a6a6dc9452586f3d14b0 to 5.
# Updated 6499a6a6dc9452586f3d14b1 to 5.
# Updated 6499a6a6dc9452586f3d14b2 to 5.
# Updated 6499a6a6dc9452586f3d14b3 to 5.
# Updated 6499a6a6dc9452586f3d14b4 to 5.
# Updated 6499a6a6dc9452586f3d14b5 to 5.
# Updated 6499a6a6dc9452586f3d14b6 to 5.
# Updated 6499a6a6dc9452586f3d14b7 to 5.
# Updated 6499a6a6dc9452586f3d14b8 to 5.
# Updated 6499a6a6dc9452586f3d14b9 to 5.
# Updated 6499a6a6dc9452586f3d14ba to 5.
# Updated 6499a6a6dc9452586f3d14bb to 5.
# Updated 6499a6a6dc9452586f3d14bc to 5.
# Updated 6499a6a6dc9452586f3d14bd to 5.
# Updated 6499a6a6dc9452586f3d14be to 5.
# Updated 6499a6a6dc9452586f3d14bf to 4.
# Updated 6499a6a6dc9452586f3d14c0 to 4.
# Updated 6499a6a6dc9452586f3d14c1 to 5.
# Updated 6499a6a6dc9452586f3d14c2 to 5.
# Updated 6499a6a6dc9452586f3d14c3 to 5.
# Updated 6499a6a6dc9452586f3d14c4 to 5.
# Updated 6499a6a6dc9452586f3d14c5 to 5.
# Updated 6499a6a6dc9452586f3d14c6 to 5.
# Updated 6499a6a6dc9452586f3d14c9 to 5.
# Updated 6499a6a6dc9452586f3d14ca to 5.
# Updated 6499a6a6dc9452586f3d14cb to 5.
# Updated 6499a6a6dc9452586f3d14cd to 5.
# Updated 6499a6a6dc9452586f3d14ce to 5.
# Updated 6499a6a6dc9452586f3d14cf to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d14d1 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d14d3 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d14d5 to 5.
# Updated 6499a6a6dc9452586f3d14d6 to 5.
# Updated 6499a6a6dc9452586f3d14d7 to 4.
# Updated 6499a6a6dc9452586f3d14d9 to 5.
# Updated 6499a6a6dc9452586f3d14da to 5.
# Updated 6499a6a6dc9452586f3d14dc to 5.
# Updated 6499a6a6dc9452586f3d14dd to 5.
# Updated 6499a6a6dc9452586f3d14de to 5.
# Updated 6499a6a6dc9452586f3d14e0 to 4.
# Updated 6499a6a6dc9452586f3d14e1 to 5.
# Updated 6499a6a6dc9452586f3d14e2 to 5.
# Updated 6499a6a6dc9452586f3d14e3 to 5.
# Updated 6499a6a6dc9452586f3d14e4 to 5.
# Updated 6499a6a6dc9452586f3d14e5 to 5.
# Updated 6499a6a6dc9452586f3d14e6 to 5.
# Updated 6499a6a6dc9452586f3d14e7 to 5.
# Updated 6499a6a6dc9452586f3d14e8 to 5.
# Updated 6499a6a6dc9452586f3d14e9 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d14eb to 5.
# Updated 6499a6a6dc9452586f3d14ec to 5.
# Updated 6499a6a6dc9452586f3d14ed to 5.
# Updated 6499a6a6dc9452586f3d14ee to 5.
# Updated 6499a6a6dc9452586f3d14ef to 5.
# Updated 6499a6a6dc9452586f3d14f0 to 5.
# Updated 6499a6a6dc9452586f3d14f1 to 5.
# Updated 6499a6a6dc9452586f3d14f2 to 5.
# Updated 6499a6a6dc9452586f3d14f4 to 5.
# Updated 6499a6a6dc9452586f3d14f5 to 5.
# Updated 6499a6a6dc9452586f3d14f6 to 5.
# Updated 6499a6a6dc9452586f3d14f7 to 5.
# Updated 6499a6a6dc9452586f3d14f8 to 5.
# Updated 6499a6a6dc9452586f3d14f9 to 5.
# Updated 6499a6a6dc9452586f3d14fa to 5.
# Updated 6499a6a6dc9452586f3d14fb to 5.
# Updated 6499a6a6dc9452586f3d14fc to 5.
# Updated 6499a6a6dc9452586f3d14fd to 5.
# Updated 6499a6a6dc9452586f3d14fe to 5.
# Updated 6499a6a6dc9452586f3d14ff to 5.
# Updated 6499a6a6dc9452586f3d1500 to 5.
# Updated 6499a6a6dc9452586f3d1502 to 5.
# Updated 6499a6a6dc9452586f3d1503 to 5.
# Updated 6499a6a6dc9452586f3d1504 to 5.
# Updated 6499a6a6dc9452586f3d1505 to 5.
# Updated 6499a6a6dc9452586f3d1506 to 5.
# Updated 6499a6a6dc9452586f3d1507 to 5.
# Updated 6499a6a6dc9452586f3d1508 to 5.
# Updated 6499a6a6dc9452586f3d1509 to 4.
# Updated 6499a6a6dc9452586f3d150a to 5.
# Updated 6499a6a6dc9452586f3d150b to 5.
# Updated 6499a6a6dc9452586f3d150c to 5.
# Updated 6499a6a6dc9452586f3d150d to 4.
# Updated 6499a6a6dc9452586f3d150e to 4.
# Updated 6499a6a6dc9452586f3d150f to 5.
# Updated 6499a6a6dc9452586f3d1510 to 5.
# Updated 6499a6a6dc9452586f3d1511 to 5.
# Updated 6499a6a6dc9452586f3d1512 to 5.
# Updated 6499a6a6dc9452586f3d1513 to 5.
# Updated 6499a6a6dc9452586f3d1514 to 5.
# Updated 6499a6a6dc9452586f3d1515 to 5.
# Updated 6499a6a6dc9452586f3d1516 to 4.
# Updated 6499a6a6dc9452586f3d1518 to 5.
# Updated 6499a6a6dc9452586f3d1519 to 5.
# Updated 6499a6a6dc9452586f3d151c to 5.
# Updated 6499a6a6dc9452586f3d151d to 5.
# Updated 6499a6a6dc9452586f3d151e to 5.
# Updated 6499a6a6dc9452586f3d151f to 5.
# Updated 6499a6a6dc9452586f3d1520 to 5.
# Updated 6499a6a6dc9452586f3d1521 to 5.
# Updated 6499a6a6dc9452586f3d1522 to 5.
# Updated 6499a6a6dc9452586f3d1524 to 5.
# Updated 6499a6a6dc9452586f3d1525 to 5.
# Updated 6499a6a6dc9452586f3d1526 to 3.
# Updated 6499a6a6dc9452586f3d1528 to 5.
# Updated 6499a6a6dc9452586f3d1529 to 5.
# Updated 6499a6a6dc9452586f3d152b to 5.
# Updated 6499a6a6dc9452586f3d152c to 5.
# Updated 6499a6a6dc9452586f3d152d to 5.
# Updated 6499a6a6dc9452586f3d152e to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1530 to 5.
# Updated 6499a6a6dc9452586f3d1532 to 5.
# Updated 6499a6a6dc9452586f3d1533 to 5.
# Updated 6499a6a6dc9452586f3d1535 to 5.
# Updated 6499a6a6dc9452586f3d1538 to 5.
# Updated 6499a6a6dc9452586f3d153a to 4.
# Updated 6499a6a6dc9452586f3d153b to 5.
# Updated 6499a6a6dc9452586f3d153c to 5.
# Updated 6499a6a6dc9452586f3d153e to 5.
# Updated 6499a6a6dc9452586f3d153f to 5.
# Updated 6499a6a6dc9452586f3d1540 to 5.
# Updated 6499a6a6dc9452586f3d1543 to 5.
# Updated 6499a6a6dc9452586f3d1544 to 5.
# Updated 6499a6a6dc9452586f3d1547 to 5.
# Updated 6499a6a6dc9452586f3d1548 to 4.
# Updated 6499a6a6dc9452586f3d154a to 5.
# Updated 6499a6a6dc9452586f3d154b to 5.
# Updated 6499a6a6dc9452586f3d154d to 5.
# Updated 6499a6a6dc9452586f3d154f to 5.
# Updated 6499a6a6dc9452586f3d1550 to 5.
# Updated 6499a6a6dc9452586f3d1552 to 5.
# Updated 6499a6a6dc9452586f3d1553 to 5.
# Updated 6499a6a6dc9452586f3d1554 to 5.
# Updated 6499a6a6dc9452586f3d1555 to 2.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1557 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1559 to 5.
# Updated 6499a6a6dc9452586f3d155c to 5.
# Updated 6499a6a6dc9452586f3d155d to 5.
# Updated 6499a6a6dc9452586f3d1560 to 4.
# Updated 6499a6a6dc9452586f3d1562 to 5.
# Updated 6499a6a6dc9452586f3d1564 to 4.
# Updated 6499a6a6dc9452586f3d1565 to 3.
# Updated 6499a6a6dc9452586f3d156b to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d156d to 5.
# Updated 6499a6a6dc9452586f3d1571 to 5.
# Updated 6499a6a6dc9452586f3d1573 to 5.
# Updated 6499a6a6dc9452586f3d1574 to 5.
# Updated 6499a6a6dc9452586f3d1576 to 5.
# Updated 6499a6a6dc9452586f3d157b to 4.
# Updated 6499a6a6dc9452586f3d157d to 5.
# Updated 6499a6a6dc9452586f3d157e to 5.
# Updated 6499a6a6dc9452586f3d157f to 5.
# Updated 6499a6a6dc9452586f3d1581 to 5.
# Updated 6499a6a6dc9452586f3d1583 to 5.
# Updated 6499a6a6dc9452586f3d1586 to 5.
# Updated 6499a6a6dc9452586f3d1587 to 5.
# Updated 6499a6a6dc9452586f3d1588 to 5.
# Updated 6499a6a6dc9452586f3d1589 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d158b to 5.
# Updated 6499a6a6dc9452586f3d1592 to 5.
# Updated 6499a6a6dc9452586f3d1593 to 4.
# Updated 6499a6a6dc9452586f3d1595 to 5.
# Updated 6499a6a6dc9452586f3d1597 to 3.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d159f to 5.
# Updated 6499a6a6dc9452586f3d15a0 to 5.
# Updated 6499a6a6dc9452586f3d15a3 to 5.
# Updated 6499a6a6dc9452586f3d15a4 to 4.
# Updated 6499a6a6dc9452586f3d15a6 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d15aa to 5.
# Updated 6499a6a6dc9452586f3d15ad to 5.
# Updated 6499a6a6dc9452586f3d15b1 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d15b6 to 4.
# Updated 6499a6a6dc9452586f3d15b7 to 5.
# Updated 6499a6a6dc9452586f3d15b8 to 4.
# Updated 6499a6a6dc9452586f3d15b9 to 5.
# Updated 6499a6a6dc9452586f3d15ba to 5.
# Updated 6499a6a6dc9452586f3d15bb to 5.
# Updated 6499a6a6dc9452586f3d15bc to 4.
# Updated 6499a6a6dc9452586f3d15bd to 3.
# Updated 6499a6a6dc9452586f3d15be to 4.
# Updated 6499a6a6dc9452586f3d15bf to 5.
# Updated 6499a6a6dc9452586f3d15c1 to 5.
# Updated 6499a6a6dc9452586f3d15c2 to 5.
# Updated 6499a6a6dc9452586f3d15c3 to 4.
# Updated 6499a6a6dc9452586f3d15c4 to 5.
# Updated 6499a6a6dc9452586f3d15c5 to 5.
# Updated 6499a6a6dc9452586f3d15c7 to 4.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d15ca to 5.
# Updated 6499a6a6dc9452586f3d15cb to 5.
# Updated 6499a6a6dc9452586f3d15cc to 5.
# Updated 6499a6a6dc9452586f3d15cd to 5.
# Updated 6499a6a6dc9452586f3d15cf to 5.
# Updated 6499a6a6dc9452586f3d15d1 to 4.
# Updated 6499a6a6dc9452586f3d15d2 to 5.
# Updated 6499a6a6dc9452586f3d15d3 to 4.
# Updated 6499a6a6dc9452586f3d15d4 to 5.
# Updated 6499a6a6dc9452586f3d15d5 to 5.
# Updated 6499a6a6dc9452586f3d15d6 to 3.
# Updated 6499a6a6dc9452586f3d15d7 to 4.
# Updated 6499a6a6dc9452586f3d15d8 to 5.
# Updated 6499a6a6dc9452586f3d15d9 to 5.
# Updated 6499a6a6dc9452586f3d15da to 5.
# Updated 6499a6a6dc9452586f3d15db to 5.
# Updated 6499a6a6dc9452586f3d15dc to 5.
# Updated 6499a6a6dc9452586f3d15dd to 4.
# Updated 6499a6a6dc9452586f3d15de to 5.
# Updated 6499a6a6dc9452586f3d15df to 5.
# Updated 6499a6a6dc9452586f3d15e0 to 2.
# Updated 6499a6a6dc9452586f3d15e2 to 3.
# Updated 6499a6a6dc9452586f3d15e3 to 5.
# Updated 6499a6a6dc9452586f3d15e4 to 5.
# Updated 6499a6a6dc9452586f3d15e5 to 5.
# Updated 6499a6a6dc9452586f3d15e7 to 5.
# Updated 6499a6a6dc9452586f3d15e8 to 5.
# Updated 6499a6a6dc9452586f3d15e9 to 5.
# Updated 6499a6a6dc9452586f3d15ea to 5.
# Updated 6499a6a6dc9452586f3d15eb to 5.
# Updated 6499a6a6dc9452586f3d15ec to 5.
# Updated 6499a6a6dc9452586f3d15ed to 5.
# Updated 6499a6a6dc9452586f3d15f0 to 5.
# Updated 6499a6a6dc9452586f3d15f1 to 4.
# Updated 6499a6a6dc9452586f3d15f2 to 5.
# Updated 6499a6a6dc9452586f3d15f3 to 4.
# Updated 6499a6a6dc9452586f3d15f4 to 5.
# Updated 6499a6a6dc9452586f3d15f5 to 5.
# Updated 6499a6a6dc9452586f3d15f6 to 5.
# Updated 6499a6a6dc9452586f3d15f7 to 5.
# Updated 6499a6a6dc9452586f3d15f8 to 5.
# Updated 6499a6a6dc9452586f3d15f9 to 5.
# Updated 6499a6a6dc9452586f3d15fa to 5.
# Updated 6499a6a6dc9452586f3d15fc to 5.
# Updated 6499a6a6dc9452586f3d15fd to 5.
# Updated 6499a6a6dc9452586f3d15fe to 5.
# Updated 6499a6a6dc9452586f3d15ff to 5.
# Updated 6499a6a6dc9452586f3d1600 to 5.
# Updated 6499a6a6dc9452586f3d1601 to 5.
# Updated 6499a6a6dc9452586f3d1602 to 4.
# Updated 6499a6a6dc9452586f3d1603 to 5.
# Updated 6499a6a6dc9452586f3d1604 to 5.
# Updated 6499a6a6dc9452586f3d1606 to 5.
# Updated 6499a6a6dc9452586f3d1607 to 5.
# Updated 6499a6a6dc9452586f3d1608 to 4.
# Updated 6499a6a6dc9452586f3d1609 to 3.
# Updated 6499a6a6dc9452586f3d160a to 3.
# Updated 6499a6a6dc9452586f3d160b to 5.
# Updated 6499a6a6dc9452586f3d160c to 5.
# Updated 6499a6a6dc9452586f3d160d to 5.
# Updated 6499a6a6dc9452586f3d1610 to 5.
# Updated 6499a6a6dc9452586f3d1611 to 5.
# Updated 6499a6a6dc9452586f3d1613 to 4.
# Updated 6499a6a6dc9452586f3d1614 to 5.
# Updated 6499a6a6dc9452586f3d1615 to 5.
# Updated 6499a6a6dc9452586f3d1616 to 5.
# Updated 6499a6a6dc9452586f3d1617 to 5.
# Updated 6499a6a6dc9452586f3d1618 to 5.
# Updated 6499a6a6dc9452586f3d1619 to 5.
# Updated 6499a6a6dc9452586f3d161a to 5.
# Updated 6499a6a6dc9452586f3d161b to 5.
# Updated 6499a6a6dc9452586f3d161c to 5.
# Updated 6499a6a6dc9452586f3d161d to 5.
# Updated 6499a6a6dc9452586f3d161e to 4.
# Updated 6499a6a6dc9452586f3d161f to 5.
# Updated 6499a6a6dc9452586f3d1620 to 5.
# Updated 6499a6a6dc9452586f3d1621 to 5.
# Updated 6499a6a6dc9452586f3d1622 to 5.
# Updated 6499a6a6dc9452586f3d1624 to 5.
# Updated 6499a6a6dc9452586f3d1625 to 5.
# Updated 6499a6a6dc9452586f3d1626 to 5.
# Updated 6499a6a6dc9452586f3d1627 to 5.
# Updated 6499a6a6dc9452586f3d1628 to 5.
# Updated 6499a6a6dc9452586f3d1629 to 4.
# Updated 6499a6a6dc9452586f3d162a to 5.
# Updated 6499a6a6dc9452586f3d162c to 5.
# Updated 6499a6a6dc9452586f3d162d to 5.
# Updated 6499a6a6dc9452586f3d162e to 5.
# Updated 6499a6a6dc9452586f3d162f to 4.
# Updated 6499a6a6dc9452586f3d1630 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1632 to 5.
# Updated 6499a6a6dc9452586f3d1633 to 5.
# Updated 6499a6a6dc9452586f3d1634 to 5.
# Updated 6499a6a6dc9452586f3d1635 to 5.
# Updated 6499a6a6dc9452586f3d1637 to 5.
# Updated 6499a6a6dc9452586f3d1638 to 5.
# Updated 6499a6a6dc9452586f3d1639 to 5.
# Updated 6499a6a6dc9452586f3d163a to 5.
# Updated 6499a6a6dc9452586f3d163b to 5.
# Updated 6499a6a6dc9452586f3d163c to 5.
# Updated 6499a6a6dc9452586f3d163d to 4.
# Updated 6499a6a6dc9452586f3d163f to 5.
# Updated 6499a6a6dc9452586f3d1640 to 5.
# Updated 6499a6a6dc9452586f3d1641 to 5.
# Updated 6499a6a6dc9452586f3d1642 to 5.
# Updated 6499a6a6dc9452586f3d1643 to 5.
# Updated 6499a6a6dc9452586f3d1644 to 5.
# Updated 6499a6a6dc9452586f3d1645 to 5.
# Updated 6499a6a6dc9452586f3d1646 to 5.
# Updated 6499a6a6dc9452586f3d1647 to 5.
# Updated 6499a6a6dc9452586f3d1648 to 5.
# Updated 6499a6a6dc9452586f3d164a to 5.
# Updated 6499a6a6dc9452586f3d164b to 5.
# Updated 6499a6a6dc9452586f3d164c to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d164e to 5.
# Updated 6499a6a6dc9452586f3d164f to 5.
# Updated 6499a6a6dc9452586f3d1650 to 5.
# Updated 6499a6a6dc9452586f3d1651 to 4.
# Updated 6499a6a6dc9452586f3d1652 to 5.
# Updated 6499a6a6dc9452586f3d1653 to 5.
# Updated 6499a6a6dc9452586f3d1654 to 5.
# Updated 6499a6a6dc9452586f3d1655 to 5.
# Updated 6499a6a6dc9452586f3d1656 to 5.
# Updated 6499a6a6dc9452586f3d1657 to 4.
# Updated 6499a6a6dc9452586f3d1658 to 5.
# Updated 6499a6a6dc9452586f3d1659 to 5.
# Updated 6499a6a6dc9452586f3d165a to 5.
# Updated 6499a6a6dc9452586f3d165b to 5.
# Updated 6499a6a6dc9452586f3d165c to 5.
# Updated 6499a6a6dc9452586f3d165d to 4.
# Updated 6499a6a6dc9452586f3d165e to 5.
# Updated 6499a6a6dc9452586f3d165f to 5.
# Updated 6499a6a6dc9452586f3d1660 to 5.
# Updated 6499a6a6dc9452586f3d1661 to 5.
# Updated 6499a6a6dc9452586f3d1662 to 5.
# Updated 6499a6a6dc9452586f3d1664 to 5.
# Updated 6499a6a6dc9452586f3d1665 to 5.
# Updated 6499a6a6dc9452586f3d1666 to 5.
# Updated 6499a6a6dc9452586f3d1667 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1669 to 5.
# Updated 6499a6a6dc9452586f3d166a to 5.
# Updated 6499a6a6dc9452586f3d166b to 5.
# Updated 6499a6a6dc9452586f3d166c to 5.
# Updated 6499a6a6dc9452586f3d166d to 5.
# Updated 6499a6a6dc9452586f3d166e to 5.
# Updated 6499a6a6dc9452586f3d166f to 5.
# Updated 6499a6a6dc9452586f3d1670 to 5.
# Updated 6499a6a6dc9452586f3d1672 to 5.
# Updated 6499a6a6dc9452586f3d1673 to 5.
# Updated 6499a6a6dc9452586f3d1675 to 5.
# Updated 6499a6a6dc9452586f3d1676 to 4.
# Updated 6499a6a6dc9452586f3d1677 to 4.
# Updated 6499a6a6dc9452586f3d1678 to 5.
# Updated 6499a6a6dc9452586f3d1679 to 4.
# Updated 6499a6a6dc9452586f3d167a to 5.
# Updated 6499a6a6dc9452586f3d167b to 5.
# Updated 6499a6a6dc9452586f3d167c to 5.
# Updated 6499a6a6dc9452586f3d167d to 5.
# Updated 6499a6a6dc9452586f3d167e to 5.
# Updated 6499a6a6dc9452586f3d1680 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1682 to 5.
# Updated 6499a6a6dc9452586f3d1683 to 5.
# Updated 6499a6a6dc9452586f3d1684 to 5.
# Updated 6499a6a6dc9452586f3d1688 to 5.
# Updated 6499a6a6dc9452586f3d1689 to 4.
# Updated 6499a6a6dc9452586f3d168a to 5.
# Updated 6499a6a6dc9452586f3d168b to 5.
# Updated 6499a6a6dc9452586f3d168c to 5.
# Updated 6499a6a6dc9452586f3d168e to 5.
# Updated 6499a6a6dc9452586f3d168f to 5.
# Updated 6499a6a6dc9452586f3d1690 to 5.
# Updated 6499a6a6dc9452586f3d1691 to 5.
# Updated 6499a6a6dc9452586f3d1692 to 5.
# Updated 6499a6a6dc9452586f3d1694 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1696 to 5.
# Updated 6499a6a6dc9452586f3d1697 to 5.
# Updated 6499a6a6dc9452586f3d1698 to 4.
# Updated 6499a6a6dc9452586f3d1699 to 5.
# Updated 6499a6a6dc9452586f3d169a to 5.
# Updated 6499a6a6dc9452586f3d169b to 4.
# Updated 6499a6a6dc9452586f3d169c to 5.
# Updated 6499a6a6dc9452586f3d169d to 5.
# Updated 6499a6a6dc9452586f3d169e to 5.
# Updated 6499a6a6dc9452586f3d169f to 5.
# Updated 6499a6a6dc9452586f3d16a0 to 2.
# Updated 6499a6a6dc9452586f3d16a1 to 5.
# Updated 6499a6a6dc9452586f3d16a2 to 4.
# Updated 6499a6a6dc9452586f3d16a3 to 5.
# Updated 6499a6a6dc9452586f3d16a4 to 5.
# Updated 6499a6a6dc9452586f3d16a5 to 5.
# Updated 6499a6a6dc9452586f3d16a6 to 5.
# Updated 6499a6a6dc9452586f3d16a7 to 5.
# Updated 6499a6a6dc9452586f3d16a8 to 5.
# Updated 6499a6a6dc9452586f3d16a9 to 5.
# Updated 6499a6a6dc9452586f3d16aa to 5.
# Updated 6499a6a6dc9452586f3d16ab to 5.
# Updated 6499a6a6dc9452586f3d16ac to 5.
# Updated 6499a6a6dc9452586f3d16ad to 5.
# Updated 6499a6a6dc9452586f3d16ae to 5.
# Updated 6499a6a6dc9452586f3d16af to 5.
# Updated 6499a6a6dc9452586f3d16b0 to 5.
# Updated 6499a6a6dc9452586f3d16b1 to 5.
# Updated 6499a6a6dc9452586f3d16b2 to 5.
# Updated 6499a6a6dc9452586f3d16b3 to 5.
# Updated 6499a6a6dc9452586f3d16b4 to 5.
# Updated 6499a6a6dc9452586f3d16b5 to 5.
# Updated 6499a6a6dc9452586f3d16b6 to 5.
# Updated 6499a6a6dc9452586f3d16b9 to 5.
# Updated 6499a6a6dc9452586f3d16bb to 5.
# Updated 6499a6a6dc9452586f3d16bc to 5.
# Updated 6499a6a6dc9452586f3d16bd to 5.
# Updated 6499a6a6dc9452586f3d16be to 5.
# Updated 6499a6a6dc9452586f3d16bf to 5.
# Updated 6499a6a6dc9452586f3d16c0 to 5.
# Updated 6499a6a6dc9452586f3d16c2 to 5.
# Updated 6499a6a6dc9452586f3d16c3 to 5.
# Updated 6499a6a6dc9452586f3d16c4 to 5.
# Updated 6499a6a6dc9452586f3d16c5 to 5.
# Updated 6499a6a6dc9452586f3d16c6 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d16c8 to 5.
# Updated 6499a6a6dc9452586f3d16c9 to 5.
# Updated 6499a6a6dc9452586f3d16ca to 5.
# Updated 6499a6a6dc9452586f3d16ce to 5.
# Updated 6499a6a6dc9452586f3d16cf to 1.
# Updated 6499a6a6dc9452586f3d16d0 to 5.
# Updated 6499a6a6dc9452586f3d16d1 to 5.
# Updated 6499a6a6dc9452586f3d16d2 to 4.
# Updated 6499a6a6dc9452586f3d16d3 to 5.
# Updated 6499a6a6dc9452586f3d16d4 to 5.
# Updated 6499a6a6dc9452586f3d16d5 to 5.
# Updated 6499a6a6dc9452586f3d16d6 to 5.
# Updated 6499a6a6dc9452586f3d16d7 to 5.
# Updated 6499a6a6dc9452586f3d16d8 to 3.
# Updated 6499a6a6dc9452586f3d16d9 to 5.
# Updated 6499a6a6dc9452586f3d16da to 3.
# Updated 6499a6a6dc9452586f3d16db to 5.
# Updated 6499a6a6dc9452586f3d16dc to 5.
# Updated 6499a6a6dc9452586f3d16dd to 5.
# Updated 6499a6a6dc9452586f3d16de to 5.
# Updated 6499a6a6dc9452586f3d16df to 5.
# Updated 6499a6a6dc9452586f3d16e0 to 5.
# Updated 6499a6a6dc9452586f3d16e1 to 5.
# Updated 6499a6a6dc9452586f3d16e2 to 5.
# Updated 6499a6a6dc9452586f3d16e3 to 5.
# Updated 6499a6a6dc9452586f3d16e4 to 5.
# Updated 6499a6a6dc9452586f3d16e5 to 5.
# Updated 6499a6a6dc9452586f3d16e6 to 5.
# Updated 6499a6a6dc9452586f3d16e7 to 5.
# Updated 6499a6a6dc9452586f3d16e8 to 5.
# Updated 6499a6a6dc9452586f3d16e9 to 5.
# Updated 6499a6a6dc9452586f3d16ea to 5.
# Updated 6499a6a6dc9452586f3d16eb to 4.
# Updated 6499a6a6dc9452586f3d16ec to 5.
# Updated 6499a6a6dc9452586f3d16ed to 3.
# Updated 6499a6a6dc9452586f3d16ee to 5.
# Updated 6499a6a6dc9452586f3d16ef to 5.
# Updated 6499a6a6dc9452586f3d16f1 to 5.
# Updated 6499a6a6dc9452586f3d16f2 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d16f4 to 5.
# Updated 6499a6a6dc9452586f3d16f5 to 4.
# Updated 6499a6a6dc9452586f3d16f6 to 5.
# Updated 6499a6a6dc9452586f3d16f7 to 5.
# Updated 6499a6a6dc9452586f3d16f8 to 5.
# Updated 6499a6a6dc9452586f3d16f9 to 3.
# Updated 6499a6a6dc9452586f3d16fa to 5.
# Updated 6499a6a6dc9452586f3d16fb to 5.
# Updated 6499a6a6dc9452586f3d16fc to 5.
# Updated 6499a6a6dc9452586f3d16fd to 5.
# Updated 6499a6a6dc9452586f3d16fe to 5.
# Updated 6499a6a6dc9452586f3d16ff to 5.
# Updated 6499a6a6dc9452586f3d1700 to 5.
# Updated 6499a6a6dc9452586f3d1701 to 5.
# Updated 6499a6a6dc9452586f3d1702 to 5.
# Updated 6499a6a6dc9452586f3d1703 to 5.
# Updated 6499a6a6dc9452586f3d1704 to 5.
# Updated 6499a6a6dc9452586f3d1705 to 5.
# Updated 6499a6a6dc9452586f3d1706 to 5.
# Updated 6499a6a6dc9452586f3d1707 to 5.
# Updated 6499a6a6dc9452586f3d1708 to 5.
# Updated 6499a6a6dc9452586f3d1709 to 5.
# Updated 6499a6a6dc9452586f3d170a to 5.
# Updated 6499a6a6dc9452586f3d170b to 4.
# Updated 6499a6a6dc9452586f3d170c to 4.
# Updated 6499a6a6dc9452586f3d170d to 5.
# Updated 6499a6a6dc9452586f3d170e to 5.
# Updated 6499a6a6dc9452586f3d170f to 4.
# Updated 6499a6a6dc9452586f3d1710 to 5.
# Updated 6499a6a6dc9452586f3d1711 to 5.
# Updated 6499a6a6dc9452586f3d1712 to 3.
# Updated 6499a6a6dc9452586f3d1713 to 5.
# Updated 6499a6a6dc9452586f3d1714 to 5.
# Updated 6499a6a6dc9452586f3d1715 to 5.
# Updated 6499a6a6dc9452586f3d1716 to 5.
# Updated 6499a6a6dc9452586f3d1717 to 5.
# Updated 6499a6a6dc9452586f3d171a to 5.
# Updated 6499a6a6dc9452586f3d171b to 5.
# Updated 6499a6a6dc9452586f3d171c to 5.
# Updated 6499a6a6dc9452586f3d171d to 5.
# Updated 6499a6a6dc9452586f3d171e to 5.
# Updated 6499a6a6dc9452586f3d171f to 5.
# Updated 6499a6a6dc9452586f3d1720 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1722 to 5.
# Updated 6499a6a6dc9452586f3d1723 to 5.
# Updated 6499a6a6dc9452586f3d1724 to 5.
# Updated 6499a6a6dc9452586f3d1725 to 4.
# Updated 6499a6a6dc9452586f3d1726 to 5.
# Updated 6499a6a6dc9452586f3d1727 to 5.
# Updated 6499a6a6dc9452586f3d1728 to 5.
# Updated 6499a6a6dc9452586f3d1729 to 5.
# Updated 6499a6a6dc9452586f3d172a to 5.
# Updated 6499a6a6dc9452586f3d172b to 5.
# Updated 6499a6a6dc9452586f3d172c to 5.
# Updated 6499a6a6dc9452586f3d172d to 5.
# Updated 6499a6a6dc9452586f3d172e to 5.
# Updated 6499a6a6dc9452586f3d172f to 5.
# Updated 6499a6a6dc9452586f3d1730 to 5.
# Updated 6499a6a6dc9452586f3d1731 to 5.
# Updated 6499a6a6dc9452586f3d1732 to 4.
# Updated 6499a6a6dc9452586f3d1733 to 5.
# Updated 6499a6a6dc9452586f3d1734 to 5.
# Updated 6499a6a6dc9452586f3d1735 to 5.
# Updated 6499a6a6dc9452586f3d1736 to 5.
# Updated 6499a6a6dc9452586f3d1737 to 5.
# Updated 6499a6a6dc9452586f3d1738 to 5.
# Updated 6499a6a6dc9452586f3d1739 to 5.
# Updated 6499a6a6dc9452586f3d173a to 5.
# Updated 6499a6a6dc9452586f3d173b to 4.
# Updated 6499a6a6dc9452586f3d173c to 5.
# Updated 6499a6a6dc9452586f3d173d to 5.
# Updated 6499a6a6dc9452586f3d173e to 5.
# Updated 6499a6a6dc9452586f3d173f to 5.
# Updated 6499a6a6dc9452586f3d1740 to 5.
# Updated 6499a6a6dc9452586f3d1741 to 5.
# Updated 6499a6a6dc9452586f3d1742 to 5.
# Updated 6499a6a6dc9452586f3d1743 to 4.
# Updated 6499a6a6dc9452586f3d1744 to 5.
# Updated 6499a6a6dc9452586f3d1745 to 5.
# Updated 6499a6a6dc9452586f3d1746 to 5.
# Updated 6499a6a6dc9452586f3d1747 to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1749 to 5.
# Updated 6499a6a6dc9452586f3d174a to 4.
# Updated 6499a6a6dc9452586f3d174b to 5.
# Updated 6499a6a6dc9452586f3d174c to 4.
# Updated 6499a6a6dc9452586f3d174d to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d174f to 5.
# Updated 6499a6a6dc9452586f3d1750 to 2.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d1752 to 5.
# Updated 6499a6a6dc9452586f3d1753 to 5.
# Updated 6499a6a6dc9452586f3d1754 to 4.
# Updated 6499a6a6dc9452586f3d1755 to 5.
# Updated 6499a6a6dc9452586f3d1756 to 3.
# Updated 6499a6a6dc9452586f3d1757 to 4.
# Updated 6499a6a6dc9452586f3d1758 to 3.
# RatingValue is None
# RatingValue is None
# Updated 6499a6a6dc9452586f3d175b to 5.
# Updated 6499a6a6dc9452586f3d175c to 5.
# Updated 6499a6a6dc9452586f3d175d to 5.
# RatingValue is None
# Updated 6499a6a6dc9452586f3d175f to 5.
# Updated 6499a6a6dc9452586f3d1760 to 5.
# Updated 6499a6a6dc9452586f3d1761 to 5.
# Updated 6499a6a6dc9452586f3d1762 to 5.
# Updated 6499a6a6dc9452586f3d1763 to 5.
# Updated 6499a6a6dc9452586f3d1764 to 5.
# Updated 6499a6a6dc9452586f3d1765 to 5.
# ...
# RatingValue is None
# Updated 6499a6a8dc9452586f3da88b to 1.
# Updated 6499a6a8dc9452586f3da88c to 5.
# Updated 6499a6a8dc9452586f3da88d to 5.
# Updated 6499a6a8dc9452586f3da88e to 1.
# Updated 6499a6a8dc9452586f3da88f to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da891 to 5.
# Updated 6499a6a8dc9452586f3da892 to 5.
# RatingValue is None
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3da896 to 5.
# Updated 6499a6a8dc9452586f3da897 to 5.
# Updated 6499a6a8dc9452586f3da898 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da89a to 4.
# Updated 6499a6a8dc9452586f3da89b to 1.
# Updated 6499a6a8dc9452586f3da89c to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da89e to 4.
# Updated 6499a6a8dc9452586f3da89f to 5.
# Updated 6499a6a8dc9452586f3da8a0 to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8a2 to 5.
# Updated 6499a6a8dc9452586f3da8a3 to 5.
# Updated 6499a6a8dc9452586f3da8a4 to 4.
# Updated 6499a6a8dc9452586f3da8a5 to 5.
# Updated 6499a6a8dc9452586f3da8a6 to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8a8 to 5.
# Updated 6499a6a8dc9452586f3da8a9 to 5.
# Updated 6499a6a8dc9452586f3da8aa to 3.
# Updated 6499a6a8dc9452586f3da8ab to 5.
# Updated 6499a6a8dc9452586f3da8ac to 4.
# Updated 6499a6a8dc9452586f3da8ad to 5.
# RatingValue is None
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8b1 to 5.
# Updated 6499a6a8dc9452586f3da8b2 to 3.
# Updated 6499a6a8dc9452586f3da8b3 to 5.
# Updated 6499a6a8dc9452586f3da8b4 to 5.
# Updated 6499a6a8dc9452586f3da8b5 to 5.
# Updated 6499a6a8dc9452586f3da8b6 to 5.
# Updated 6499a6a8dc9452586f3da8b7 to 5.
# Updated 6499a6a8dc9452586f3da8b8 to 5.
# Updated 6499a6a8dc9452586f3da8b9 to 4.
# Updated 6499a6a8dc9452586f3da8ba to 5.
# Updated 6499a6a8dc9452586f3da8bb to 5.
# Updated 6499a6a8dc9452586f3da8bc to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8be to 5.
# Updated 6499a6a8dc9452586f3da8bf to 5.
# Updated 6499a6a8dc9452586f3da8c0 to 5.
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8c3 to 5.
# Updated 6499a6a8dc9452586f3da8c4 to 4.
# Updated 6499a6a8dc9452586f3da8c5 to 5.
# Updated 6499a6a8dc9452586f3da8c6 to 5.
# Updated 6499a6a8dc9452586f3da8c7 to 4.
# Updated 6499a6a8dc9452586f3da8c8 to 5.
# Updated 6499a6a8dc9452586f3da8c9 to 4.
# Updated 6499a6a8dc9452586f3da8ca to 5.
# Updated 6499a6a8dc9452586f3da8cb to 5.
# Updated 6499a6a8dc9452586f3da8cc to 5.
# Updated 6499a6a8dc9452586f3da8cd to 5.
# Updated 6499a6a8dc9452586f3da8ce to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8d0 to 5.
# Updated 6499a6a8dc9452586f3da8d1 to 4.
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8d4 to 5.
# Updated 6499a6a8dc9452586f3da8d5 to 5.
# Updated 6499a6a8dc9452586f3da8d6 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8d8 to 5.
# Updated 6499a6a8dc9452586f3da8d9 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8db to 4.
# Updated 6499a6a8dc9452586f3da8dc to 4.
# RatingValue is None
# RatingValue is None
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8e1 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8e3 to 5.
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8e6 to 5.
# Updated 6499a6a8dc9452586f3da8e7 to 5.
# Updated 6499a6a8dc9452586f3da8e8 to 5.
# Updated 6499a6a8dc9452586f3da8e9 to 5.
# Updated 6499a6a8dc9452586f3da8ea to 5.
# Updated 6499a6a8dc9452586f3da8eb to 3.
# Updated 6499a6a8dc9452586f3da8ec to 5.
# Updated 6499a6a8dc9452586f3da8ed to 5.
# Updated 6499a6a8dc9452586f3da8ee to 5.
# Updated 6499a6a8dc9452586f3da8ef to 5.
# Updated 6499a6a8dc9452586f3da8f0 to 4.
# Updated 6499a6a8dc9452586f3da8f1 to 5.
# Updated 6499a6a8dc9452586f3da8f2 to 5.
# Updated 6499a6a8dc9452586f3da8f3 to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8f5 to 5.
# Updated 6499a6a8dc9452586f3da8f6 to 5.
# RatingValue is None
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8fa to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8fc to 5.
# Updated 6499a6a8dc9452586f3da8fd to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da8ff to 5.
# Updated 6499a6a8dc9452586f3da900 to 5.
# Updated 6499a6a8dc9452586f3da901 to 5.
# Updated 6499a6a8dc9452586f3da902 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da904 to 5.
# Updated 6499a6a8dc9452586f3da905 to 5.
# Updated 6499a6a8dc9452586f3da906 to 1.
# Updated 6499a6a8dc9452586f3da907 to 5.
# Updated 6499a6a8dc9452586f3da908 to 5.
# Updated 6499a6a8dc9452586f3da909 to 2.
# Updated 6499a6a8dc9452586f3da90a to 5.
# Updated 6499a6a8dc9452586f3da90b to 5.
# Updated 6499a6a8dc9452586f3da90c to 5.
# Updated 6499a6a8dc9452586f3da90d to 5.
# Updated 6499a6a8dc9452586f3da90e to 5.
# Updated 6499a6a8dc9452586f3da90f to 3.
# Updated 6499a6a8dc9452586f3da910 to 5.
# Updated 6499a6a8dc9452586f3da911 to 5.
# Updated 6499a6a8dc9452586f3da912 to 3.
# Updated 6499a6a8dc9452586f3da913 to 2.
# Updated 6499a6a8dc9452586f3da914 to 4.
# Updated 6499a6a8dc9452586f3da915 to 4.
# Updated 6499a6a8dc9452586f3da916 to 5.
# Updated 6499a6a8dc9452586f3da917 to 4.
# Updated 6499a6a8dc9452586f3da918 to 5.
# Updated 6499a6a8dc9452586f3da919 to 5.
# Updated 6499a6a8dc9452586f3da91a to 5.
# Updated 6499a6a8dc9452586f3da91b to 5.
# Updated 6499a6a8dc9452586f3da91c to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da91e to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da920 to 5.
# RatingValue is None
# RatingValue is None
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3da925 to 5.
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3da928 to 5.
# Updated 6499a6a8dc9452586f3da929 to 5.
# Updated 6499a6a8dc9452586f3da92a to 5.
# Updated 6499a6a8dc9452586f3da92b to 5.
# Updated 6499a6a8dc9452586f3da92c to 5.
# Updated 6499a6a8dc9452586f3da92d to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da92f to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da931 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da933 to 5.
# Updated 6499a6a8dc9452586f3da934 to 5.
# Updated 6499a6a8dc9452586f3da935 to 4.
# Updated 6499a6a8dc9452586f3da936 to 5.
# Updated 6499a6a8dc9452586f3da937 to 4.
# Updated 6499a6a8dc9452586f3da938 to 5.
# Updated 6499a6a8dc9452586f3da939 to 4.
# Updated 6499a6a8dc9452586f3da93a to 5.
# Updated 6499a6a8dc9452586f3da93b to 5.
# Updated 6499a6a8dc9452586f3da93c to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da93e to 5.
# Updated 6499a6a8dc9452586f3da93f to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da941 to 5.
# Updated 6499a6a8dc9452586f3da942 to 5.
# Updated 6499a6a8dc9452586f3da943 to 5.
# Updated 6499a6a8dc9452586f3da944 to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da946 to 5.
# Updated 6499a6a8dc9452586f3da947 to 5.
# Updated 6499a6a8dc9452586f3da948 to 5.
# Updated 6499a6a8dc9452586f3da949 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da94b to 5.
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3da94e to 5.
# Updated 6499a6a8dc9452586f3da94f to 5.
# Updated 6499a6a8dc9452586f3da950 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da952 to 5.
# Updated 6499a6a8dc9452586f3da953 to 5.
# Updated 6499a6a8dc9452586f3da954 to 4.
# Updated 6499a6a8dc9452586f3da955 to 5.
# Updated 6499a6a8dc9452586f3da956 to 2.
# Updated 6499a6a8dc9452586f3da957 to 5.
# Updated 6499a6a8dc9452586f3da958 to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da95a to 5.
# Updated 6499a6a8dc9452586f3da95b to 5.
# Updated 6499a6a8dc9452586f3da95c to 5.
# Updated 6499a6a8dc9452586f3da95d to 5.
# Updated 6499a6a8dc9452586f3da95e to 5.
# Updated 6499a6a8dc9452586f3da95f to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da961 to 2.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da963 to 5.
# RatingValue is None
# RatingValue is None
# RatingValue is None
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3da969 to 5.
# Updated 6499a6a8dc9452586f3da96a to 5.
# Updated 6499a6a8dc9452586f3da96b to 5.
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3da96e to 5.
# Updated 6499a6a8dc9452586f3da96f to 5.
# Updated 6499a6a8dc9452586f3da970 to 4.
# Updated 6499a6a8dc9452586f3da971 to 5.
# Updated 6499a6a8dc9452586f3da972 to 4.
# Updated 6499a6a8dc9452586f3da973 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da975 to 5.
# Updated 6499a6a8dc9452586f3da976 to 5.
# RatingValue is None
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3da97a to 5.
# Updated 6499a6a8dc9452586f3da97b to 5.
# Updated 6499a6a8dc9452586f3da97c to 5.
# Updated 6499a6a8dc9452586f3da97d to 5.
# Updated 6499a6a8dc9452586f3da97e to 5.
# Updated 6499a6a8dc9452586f3da97f to 4.
# Updated 6499a6a8dc9452586f3da980 to 5.
# Updated 6499a6a8dc9452586f3da981 to 3.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da983 to 4.
# Updated 6499a6a8dc9452586f3da984 to 4.
# Updated 6499a6a8dc9452586f3da985 to 5.
# Updated 6499a6a8dc9452586f3da986 to 5.
# Updated 6499a6a8dc9452586f3da987 to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da989 to 5.
# Updated 6499a6a8dc9452586f3da98a to 1.
# Updated 6499a6a8dc9452586f3da98b to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da98d to 4.
# Updated 6499a6a8dc9452586f3da98e to 5.
# Updated 6499a6a8dc9452586f3da98f to 5.
# Updated 6499a6a8dc9452586f3da990 to 5.
# Updated 6499a6a8dc9452586f3da991 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da993 to 3.
# Updated 6499a6a8dc9452586f3da994 to 5.
# Updated 6499a6a8dc9452586f3da995 to 5.
# Updated 6499a6a8dc9452586f3da996 to 4.
# Updated 6499a6a8dc9452586f3da997 to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da999 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da99b to 2.
# Updated 6499a6a8dc9452586f3da99c to 5.
# Updated 6499a6a8dc9452586f3da99d to 2.
# Updated 6499a6a8dc9452586f3da99e to 5.
# Updated 6499a6a8dc9452586f3da99f to 5.
# Updated 6499a6a8dc9452586f3da9a0 to 5.
# Updated 6499a6a8dc9452586f3da9a1 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9a3 to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9a5 to 5.
# Updated 6499a6a8dc9452586f3da9a6 to 4.
# Updated 6499a6a8dc9452586f3da9a7 to 5.
# Updated 6499a6a8dc9452586f3da9a8 to 2.
# Updated 6499a6a8dc9452586f3da9a9 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9ab to 5.
# Updated 6499a6a8dc9452586f3da9ac to 5.
# Updated 6499a6a8dc9452586f3da9ad to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9af to 5.
# Updated 6499a6a8dc9452586f3da9b0 to 5.
# Updated 6499a6a8dc9452586f3da9b1 to 4.
# Updated 6499a6a8dc9452586f3da9b2 to 5.
# Updated 6499a6a8dc9452586f3da9b3 to 5.
# Updated 6499a6a8dc9452586f3da9b4 to 5.
# Updated 6499a6a8dc9452586f3da9b5 to 5.
# Updated 6499a6a8dc9452586f3da9b6 to 5.
# Updated 6499a6a8dc9452586f3da9b7 to 4.
# Updated 6499a6a8dc9452586f3da9b8 to 5.
# Updated 6499a6a8dc9452586f3da9b9 to 5.
# Updated 6499a6a8dc9452586f3da9ba to 5.
# Updated 6499a6a8dc9452586f3da9bb to 1.
# Updated 6499a6a8dc9452586f3da9bc to 5.
# Updated 6499a6a8dc9452586f3da9bd to 5.
# Updated 6499a6a8dc9452586f3da9be to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9c0 to 5.
# Updated 6499a6a8dc9452586f3da9c1 to 5.
# Updated 6499a6a8dc9452586f3da9c2 to 3.
# Updated 6499a6a8dc9452586f3da9c3 to 3.
# Updated 6499a6a8dc9452586f3da9c4 to 5.
# Updated 6499a6a8dc9452586f3da9c5 to 3.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9c7 to 5.
# Updated 6499a6a8dc9452586f3da9c8 to 5.
# Updated 6499a6a8dc9452586f3da9c9 to 4.
# Updated 6499a6a8dc9452586f3da9ca to 5.
# Updated 6499a6a8dc9452586f3da9cb to 5.
# Updated 6499a6a8dc9452586f3da9cc to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9ce to 5.
# Updated 6499a6a8dc9452586f3da9cf to 2.
# Updated 6499a6a8dc9452586f3da9d0 to 5.
# Updated 6499a6a8dc9452586f3da9d1 to 5.
# Updated 6499a6a8dc9452586f3da9d2 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9d4 to 3.
# Updated 6499a6a8dc9452586f3da9d5 to 5.
# Updated 6499a6a8dc9452586f3da9d6 to 5.
# Updated 6499a6a8dc9452586f3da9d7 to 5.
# Updated 6499a6a8dc9452586f3da9d8 to 4.
# Updated 6499a6a8dc9452586f3da9d9 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9db to 1.
# Updated 6499a6a8dc9452586f3da9dc to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9de to 5.
# Updated 6499a6a8dc9452586f3da9df to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9e1 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9e3 to 5.
# Updated 6499a6a8dc9452586f3da9e4 to 5.
# Updated 6499a6a8dc9452586f3da9e5 to 5.
# Updated 6499a6a8dc9452586f3da9e6 to 5.
# Updated 6499a6a8dc9452586f3da9e7 to 1.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9e9 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9eb to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3da9ed to 5.
# Updated 6499a6a8dc9452586f3da9ee to 4.
# Updated 6499a6a8dc9452586f3da9ef to 5.
# Updated 6499a6a8dc9452586f3da9f0 to 5.
# Updated 6499a6a8dc9452586f3da9f1 to 5.
# Updated 6499a6a8dc9452586f3da9f2 to 5.
# Updated 6499a6a8dc9452586f3da9f3 to 5.
# Updated 6499a6a8dc9452586f3da9f4 to 5.
# Updated 6499a6a8dc9452586f3da9f5 to 3.
# Updated 6499a6a8dc9452586f3da9f6 to 3.
# Updated 6499a6a8dc9452586f3da9f7 to 5.
# Updated 6499a6a8dc9452586f3da9f8 to 5.
# Updated 6499a6a8dc9452586f3da9f9 to 4.
# Updated 6499a6a8dc9452586f3da9fa to 5.
# Updated 6499a6a8dc9452586f3da9fb to 5.
# Updated 6499a6a8dc9452586f3da9fc to 5.
# Updated 6499a6a8dc9452586f3da9fd to 5.
# Updated 6499a6a8dc9452586f3da9fe to 3.
# Updated 6499a6a8dc9452586f3da9ff to 5.
# Updated 6499a6a8dc9452586f3daa00 to 5.
# Updated 6499a6a8dc9452586f3daa01 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa03 to 4.
# Updated 6499a6a8dc9452586f3daa04 to 5.
# Updated 6499a6a8dc9452586f3daa05 to 5.
# Updated 6499a6a8dc9452586f3daa06 to 4.
# Updated 6499a6a8dc9452586f3daa07 to 5.
# Updated 6499a6a8dc9452586f3daa08 to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa0a to 5.
# Updated 6499a6a8dc9452586f3daa0b to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa0d to 5.
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa10 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa12 to 5.
# Updated 6499a6a8dc9452586f3daa13 to 5.
# Updated 6499a6a8dc9452586f3daa14 to 5.
# Updated 6499a6a8dc9452586f3daa15 to 5.
# Updated 6499a6a8dc9452586f3daa16 to 5.
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa19 to 5.
# Updated 6499a6a8dc9452586f3daa1a to 5.
# Updated 6499a6a8dc9452586f3daa1b to 5.
# Updated 6499a6a8dc9452586f3daa1c to 4.
# Updated 6499a6a8dc9452586f3daa1d to 5.
# Updated 6499a6a8dc9452586f3daa1e to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa20 to 5.
# Updated 6499a6a8dc9452586f3daa21 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa23 to 2.
# Updated 6499a6a8dc9452586f3daa24 to 5.
# Updated 6499a6a8dc9452586f3daa25 to 5.
# Updated 6499a6a8dc9452586f3daa26 to 5.
# Updated 6499a6a8dc9452586f3daa27 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa29 to 5.
# Updated 6499a6a8dc9452586f3daa2a to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa2c to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa2e to 4.
# Updated 6499a6a8dc9452586f3daa2f to 5.
# Updated 6499a6a8dc9452586f3daa30 to 5.
# Updated 6499a6a8dc9452586f3daa31 to 5.
# Updated 6499a6a8dc9452586f3daa32 to 5.
# Updated 6499a6a8dc9452586f3daa33 to 3.
# Updated 6499a6a8dc9452586f3daa34 to 5.
# Updated 6499a6a8dc9452586f3daa35 to 4.
# Updated 6499a6a8dc9452586f3daa36 to 5.
# Updated 6499a6a8dc9452586f3daa37 to 5.
# Updated 6499a6a8dc9452586f3daa38 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa3a to 4.
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa3d to 5.
# Updated 6499a6a8dc9452586f3daa3e to 5.
# Updated 6499a6a8dc9452586f3daa3f to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa41 to 5.
# Updated 6499a6a8dc9452586f3daa42 to 3.
# Updated 6499a6a8dc9452586f3daa43 to 5.
# Updated 6499a6a8dc9452586f3daa44 to 5.
# Updated 6499a6a8dc9452586f3daa45 to 5.
# Updated 6499a6a8dc9452586f3daa46 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa48 to 4.
# Updated 6499a6a8dc9452586f3daa49 to 4.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa4b to 5.
# Updated 6499a6a8dc9452586f3daa4c to 1.
# Updated 6499a6a8dc9452586f3daa4d to 5.
# Updated 6499a6a8dc9452586f3daa4e to 5.
# Updated 6499a6a8dc9452586f3daa4f to 5.
# RatingValue is None
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa52 to 5.
# Updated 6499a6a8dc9452586f3daa53 to 5.
# RatingValue is None
# Updated 6499a6a8dc9452586f3daa55 to 5.
# Updated 6499a6a8dc9452586f3daa56 to 5.
# Updated 6499a6a8dc9452586f3daa57 to 4.
# RatingValue is None

# %%
# Check that the coordinates and rating value are now numbers
fields = ["geocode.longitude", "geocode.latitude", "RatingValue"]
data_type_dictionary = {}
for field in fields:
    data_type_dictionary[field] = {"$type":1}
results = establishments.find_one({}, data_type_dictionary)

# Display results
results
# Out:
# {'_id': ObjectId('6499a6a6dc9452586f3d11dc'),
#  'geocode': {'longitude': 'int', 'latitude': 'int'},
#  'RatingValue': 'int'}
